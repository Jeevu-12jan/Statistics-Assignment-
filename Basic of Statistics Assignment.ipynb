# %%
#Q.1 . Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss
nominal, ordinal, interval, and ratio scales.

Ans. 
Nominal: Categories with no order. E.g., Red, Blue.
Ordinal: Categories with a defined order, but unequal intervals. E.g., Rank positions.
Interval: Numeric scales with equal intervals, but no true zero. E.g., Temperature in Celsius.
Ratio: Numeric scales with equal intervals and a true zero. E.g., Weight, Height.

# %% [raw]
# #Q.2
# What are the measures of central tendency, and when should you use each? Discuss the mean, median,
# and mode with examples and situations where each is appropriate.
#
# Ans.
#
# Measures of central tendency are statistical tools used to summarize a set of data by identifying the central point or typical value around which other data points are distributed. The three most commonly used measures of central tendency are the mean, median, and mode.
#
# Mean: The mean is the average of all the values in a dataset. It is calculated by adding up all the data points and then dividing by the number of data points.The mean is appropriate when the data is normally distributed (i.e., follows a symmetric bell curve).
# Median: The median is the middle value in a dataset when the data points are arranged in ascending or descending order. If the dataset has an odd number of values, the median is the middle value. If there is an even number of values, the median is the average of the two middle values.The median is useful when the data is skewed or contains outliers, because it is not affected by extreme values.
# It is often preferred when dealing with ordinal data (ranked categories) or skewed interval/ratio data.
# Mode:The mode is the value that appears most frequently in a dataset. Unlike the mean and median, the mode can be used with nominal (categorical) data, as it identifies the most common category.The mode is appropriate for nominal data where you want to find the most common category (e.g., most popular product, most common color).

# %% [raw]
# #Q.3
#  Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?
#
# Ans.
# Dispersion refers to the spread or variability of a dataset, describing how much the data points differ from the central tendency (mean, median, or mode) of the data. A dataset with high dispersion has values that are spread out widely from the center, while a dataset with low dispersion has values that are closely clustered around the center.
# Variance: Variance measures the average squared deviation of each data point from the mean. It gives a numerical value indicating the degree of spread in the data: a higher variance means the data points are more spread out, and a lower variance means they are more tightly clustered around the mean.
# Standard Deviation: The standard deviation is the square root of the variance. It is the most commonly used measure of dispersion because it provides a measure of spread in the original units of the data, making it more interpretable than variance.

# %% [raw]
# #Q.4 What is a box plot, and what can it tell you about the distribution of data?
# Ans.
#
# A box plot (also called a box-and-whisker plot) is a graphical representation of the distribution of a dataset, showing its central tendency, spread, and outliers. It is a concise and informative way to visualize the range, quartiles, and potential outliers in a dataset.
#
# |--------|-------------------------|----------|
# Min     Q1           Median       Q3        Max
#
# The box is drawn between Q1 and Q3, with a line inside the box indicating the median.
# The whiskers extend from the box to the minimum and maximum values, unless outliers are present.
# Outliers are typically marked as individual points beyond the whisker

# %% [raw]
# #Q.5 . Discuss the role of random sampling in making inferences about populations.
# Ans. Random sampling is a method of selecting individuals from a population in such a way that every member of the population has an equal chance of being chosen. The selection of each individual is independent of others, meaning that the choice of one individual does not affect the probability of choosing any other individual.
#
# Simple Random Sampling: Every individual in the population has an equal chance of being selected.
# Stratified Sampling: The population is divided into subgroups (strata) based on specific characteristics, and samples are drawn randomly from each subgroup.
# Systematic Sampling: Every n-th individual is selected from a list of the population after a random starting point.
# Cluster Sampling: The population is divided into clusters, and entire clusters are randomly selected for sampling.

# %% [raw]
# #Q.6  Explain the concept of skewness and its types. How does skewness affect the interpretation of data?
# Ans. Skewness is the measure of symmetricity which is inclined to some side. Skewness divided to three types: No Skewness, Positive Skewness, Negative Skewness. Skewness affects the interpretation of data in following ways:
# In skewed distributions, outliers (extremely high or low values) may influence the mean more than the median, leading to a misinterpretation of the "average" value.
# In skewed distributions, the mean is sensitive to extreme values (outliers). In positive skew, the mean is pulled to the right, and in negative skew, the mean is pulled to the left.

# %% [raw]
# #Q.7 What is the interquartile range (IQR), and how is it used to detect outliers?
# Ans.
# he Interquartile Range (IQR) is a measure of statistical dispersion that quantifies the spread of the middle 50% of a dataset. It is calculated as the difference between the third quartile (Q3) and the first quartile (Q1), representing the range between the 75th percentile and the 25th percentile of the data.
#
# Outlier Detection Using IQR
# Outliers can be detected using the 1.5 * IQR rule, which establishes a threshold beyond which values are considered extreme outliers. The steps to detect outliers using the IQR are as follows:
#
# Calculate the IQR:
# First, determine the first quartile (Q1), third quartile (Q3), and the IQR itself:
# IQR =  Q3- Q1
# Determine the lower and upper bounds:
# Lower bound: 𝑄1−1.5×IQR
# Upper bound: 𝑄3+1.5×IQR
# Identify outliers:
# Outliers are any data points that fall below the lower bound or above the upper bound.
# If a data point is less than the lower bound or greater than the upper bound, it is considered an outlier.

# %% [raw]
# #Q.8  Discuss the conditions under which the binomial distribution is used.
# Ans.The binomial distribution is appropriate for modeling the number of successes in a fixed number of independent trials, each with two possible outcomes and a constant probability of success. When these conditions are met, the binomial distribution provides a powerful tool for calculating the probabilities of different numbers of successes, allowing for decision-making and hypothesis testing in various fields such as medicine, quality control, and social sciences. However, if any of these conditions are violated (e.g., varying probabilities or dependent trials), a different statistical model may be more appropriate.

# %% [raw]
# #Q.9 Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule).
# Ans. The normal distribution is a fundamental probability distribution that is symmetric, bell-shaped, and described by the mean and standard deviation.
# The empirical rule (68-95-99.7 rule) provides an easy way to understand how data are distributed in a normal distribution:
# 68% of data fall within 1 standard deviation,
# 95% fall within 2 standard deviations, and
# 99.7% fall within 3 standard deviations.
# These properties and rules help in understanding the spread of data, making predictions, and identifying outliers in a dataset that follows a normal distribution.The normal distribution is a fundamental probability distribution that is symmetric, bell-shaped, and described by the mean and standard deviation.
# The empirical rule (68-95-99.7 rule) provides an easy way to understand how data are distributed in a normal distribution:
# 68% of data fall within 1 standard deviation,
# 95% fall within 2 standard deviations, and
# 99.7% fall within 3 standard deviations.
# These properties and rules help in understanding the spread of data, making predictions, and identifying outliers in a dataset that follows a normal distribution.

# %% [markdown]
# #Q.10
#
# Real-life Example of a Poisson Process:
# A common real-life example of a Poisson process is the arrival of customers at a bank. Suppose we are interested in the number of customers who arrive at the bank within a specific time interval, say 1 hour. If the customers arrive independently of each other and at a constant average rate, this situation can be modeled as a Poisson process.
#
# Problem Setup:
# The average number of customers arriving at the bank per hour is 5 (i.e., 𝜆=5)
# We are interested in calculating the probability that exactly 3 customers arrive within the next 1 hour.
# Poisson Distribution Formula:
# The Poisson distribution is given by the formula:
#
# 𝑃(𝑋=𝑘)=𝜆𝑘𝑒−𝜆
# /𝑘!
# Where:
# λ is the average rate of events (in this case, 5 customers per hour),
# k is the number of events we are interested in (in this case, 3 customers),
# e is Euler's number (approximately 2.71828),
# k! is the factorial of 𝑘
# Calculating the Probability:
# Given:
# λ=5,
# k=3,
# We can plug these values into the formula:
# P(X=3)= 5^3e^-5/ 3!
#
# First, calculate each term:
#
# 5^3=125
# e^-5≈0.006737947
# 3!=3×2×1=6
# Now substitute these values into the formula:
# 𝑃(𝑋=3)=125×0.0067379476/6
#             = 0.14058
# Final Answer:
# The probability that exactly 3 customers will arrive at the bank within the next hour is approximately 0.1406, or 14.06%.
#
# This is an example of how Poisson processes can be used to model real-world phenomena, like customer arrivals or event occurrences over a fixed period.

# %% [raw]
# #Q.11  Explain what a random variable is and differentiate between discrete and continuous random variables.
# Ans.
# Discrete random variables take on countable values (e.g., number of students in a class), and their probabilities are given by a probability mass function.
# Continuous random variables take on uncountably many values, often measured rather than counted (e.g., height or time), and their probabilities are given by a probability density function.
# Both types of random variables are essential in statistics and probability theory for modeling different kinds of random phenomena.

# %% [markdown]
# #Q.12  Provide an example dataset, calculate both covariance and correlation, and interpret the results
# Ans.![Bank data.JPG](attachment:4a05d048-3dd7-478b-9256-feb50509baf7.JPG)

# %% [raw]
# Mean of X = (1+2+3+4+5)/5 = 3
# Mean of Y = (50+55+60+65+70)/5  = 60
#
# Calculate the Covariance:

# %% [markdown]
# ![Bank data 1.JPG](attachment:eaa25aea-dae2-4040-b97f-932a3fe03093.JPG)

# %% [markdown]
# ![bank Data 2.JPG](attachment:478f96a6-54f5-4220-906f-68efe9f8cb9b.JPG)

# %% [markdown]
# ![Bank data 3.JPG](attachment:a57a1fb0-2c11-4353-b288-62da4fcfd9e4.JPG)
